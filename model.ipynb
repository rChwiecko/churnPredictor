# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/churn.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(12,10))

# %%
sns.countplot(x='Exited', data=df)
plt.title("Dist of churn")
plt.show()

# %%
sns.histplot(data=df,x='Age', kde=True)
plt.title("age distribution")
plt.show()
# Out:
# Text(0.5, 1.0, 'age distribution')

# %%
sns.scatterplot(data=df, x="CreditScore", y="Age", hue="Exited")
plt.title("credit score vs age")
# Out:
# Text(0.5, 1.0, 'credit score vs age')

# %%
sns.boxplot(x="Exited",y="Balance", data=df)
plt.title("balance distribution by churn")
# Out:
# Text(0.5, 1.0, 'balance distribution by churn')

# %%
sns.boxplot(x="Exited",y="CreditScore", data=df)
plt.title("Credit score distribution by churn")
# Out:
# Text(0.5, 1.0, 'Credit score distribution by churn')

# %%
features = df.drop("Exited",axis=1)

# %%
features
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
target = df["Exited"]

# %%
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
features = features.drop(['RowNumber', 'CustomerId','Surname'], axis=1)

# %%
features
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
features = features.dropna()

# %%
features
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
features = pd.get_dummies(features, columns=["Geography","Gender"])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train[0]
# Out:
# array([ 2.0700835 , -0.28068381,  0.33614242, -1.220817  ,  0.81148702,
#         0.6474524 ,  0.97092256,  1.5652603 ,  0.99079239, -0.57773517,
#        -0.5698444 ,  1.09499335, -1.09499335])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_model = LogisticRegression(random_state=42)

# %%
lr_model.fit(X_train, Y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)

# %%
lr_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
lr_accuracy = accuracy_score(Y_test, lr_predictions)

# %%
lr_accuracy
# Out:
# 0.811

# %%
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import xgboost as XGB

# %%
def evaluateAndSave(model, X_train, X_test, Y_train, Y_test, filename):
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(Y_test, y_pred)
    print(f"{model.__class__.__name__} Accuracy: {accuracy}")
    print(f"\nClassification Report:\n{classification_report(Y_test, y_pred)}")
    print("------------")

    with open(filename, "wb") as file:
        pickle.dump(model, file)
    
    print(f"model saved as {filename}")

# %%
xgb_model = XGB.XGBClassifier(random_state = 42)
evaluateAndSave(xgb_model, X_train, X_test, Y_train, Y_test, "XGB_model.pkl")

dt_model = DecisionTreeClassifier(random_state = 42)
evaluateAndSave(dt_model, X_train, X_test, Y_train, Y_test, "dt_model.pkl")

rf_model = RandomForestClassifier(random_state = 42)
evaluateAndSave(rf_model, X_train, X_test, Y_train, Y_test, "rf_model.pkl")

nb_model = GaussianNB()
evaluateAndSave(nb_model, X_train, X_test, Y_train, Y_test, "nb_model.pkl")

knn_model = KNeighborsClassifier()
evaluateAndSave(knn_model, X_train, X_test, Y_train, Y_test, "knn_model.pkl")

svc_model = SVC(random_state = 42)
evaluateAndSave(svc_model, X_train, X_test, Y_train, Y_test, "svc_model.pkl")
# Out:
# XGBClassifier Accuracy: 0.74
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83      1588
#            1       0.40      0.52      0.45       412
#
#     accuracy                           0.74      2000
#    macro avg       0.63      0.66      0.64      2000
# weighted avg       0.77      0.74      0.75      2000
#
# ------------
# model saved as XGB_model.pkl
# DecisionTreeClassifier Accuracy: 0.794
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      1588
#            1       0.50      0.55      0.53       412
#
#     accuracy                           0.79      2000
#    macro avg       0.69      0.70      0.70      2000
# weighted avg       0.80      0.79      0.80      2000
#
# ------------
# model saved as dt_model.pkl
# RandomForestClassifier Accuracy: 0.8625
#
# Classification Report:
# ...

# %% [markdown]
# we will select XGB as our model due to its recall on our desired class being higher

# %%
feature_importance = xgb_model.feature_importances_
feature_names = features.columns

# %%
feature_importance
# Out:
# array([0.03323952, 0.11076944, 0.03160447, 0.05313237, 0.2842107 ,
#        0.03072135, 0.19943829, 0.03563726, 0.04347951, 0.09353859,
#        0.03499266, 0.04923579, 0.        ], dtype=float32)

# %%
feature_names
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_France',
#        'Geography_Germany', 'Geography_Spain', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
feature_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance':feature_importance
})

# %%
feature_importance_df
# Out:
#               feature  importance
# 0         CreditScore    0.033240
# 1                 Age    0.110769
# 2              Tenure    0.031604
# 3             Balance    0.053132
# 4       NumOfProducts    0.284211
# 5           HasCrCard    0.030721
# 6      IsActiveMember    0.199438
# 7     EstimatedSalary    0.035637
# 8    Geography_France    0.043480
# 9   Geography_Germany    0.093539
# 10    Geography_Spain    0.034993
# 11      Gender_Female    0.049236
# 12        Gender_Male    0.000000

# %%
feature_importance_df = feature_importance_df.sort_values('importance', ascending=False)

# %%
feature_importance_df
# Out:
#               feature  importance
# 4       NumOfProducts    0.284211
# 6      IsActiveMember    0.199438
# 1                 Age    0.110769
# 9   Geography_Germany    0.093539
# 3             Balance    0.053132
# 11      Gender_Female    0.049236
# 8    Geography_France    0.043480
# 7     EstimatedSalary    0.035637
# 10    Geography_Spain    0.034993
# 0         CreditScore    0.033240
# 2              Tenure    0.031604
# 5           HasCrCard    0.030721
# 12        Gender_Male    0.000000

# %%
plt.figure(figsize=(10,6))
plt.bar(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xticks(rotation=90)
plt.xlabel("features")
plt.ylabel("importances")
plt.tight_layout()
plt.show()

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['CLV'] = df['Balance'] * df['EstimatedSalary'] / 100000

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['AgeGroup'] = pd.cut(df['Age'], bins=[0,30, 45, 60, 100], labels= ['young','middleage','senior','elder'])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features['TenureAgeRatio'] = df['Tenure'] / df['Age']

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
features = pd.get_dummies(features, drop_first=True)

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
xgb_model = XGB.XGBClassifier(random_state = 42)
evaluateAndSave(xgb_model, X_train, X_test, Y_train, Y_test, "xgb-feature-eng.pkl")
# Out:
# XGBClassifier Accuracy: 0.854
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.67      0.50      0.58       393
#
#     accuracy                           0.85      2000
#    macro avg       0.78      0.72      0.74      2000
# weighted avg       0.84      0.85      0.85      2000
#
# ------------
# model saved as xgb-feature-eng.pkl

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_resample, Y_resample = smote.fit_resample(X_train, Y_train)

# %%
evaluateAndSave(xgb_model, X_resample, X_test, Y_resample, Y_test, "xgb-smote.pkl")
# Out:
# XGBClassifier Accuracy: 0.8545
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1607
#            1       0.65      0.55      0.60       393
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.74      0.75      2000
# weighted avg       0.85      0.85      0.85      2000
#
# ------------
# model saved as xgb-smote.pkl

# %% [markdown]
# model is an improvment

# %%
from sklearn.ensemble import VotingClassifier

# %%
vc = VotingClassifier(
    estimators=[('xgboost', XGB.XGBClassifier(random_state=42)), ("rf", RandomForestClassifier(random_state=42)), ("svm", SVC(random_state=42, probability=True))],
    voting='soft'
)

# %%
evaluateAndSave(vc, X_resample, X_test, Y_resample, Y_test, 'voting-clf.pkl')
# Out:
# VotingClassifier Accuracy: 0.8615
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      1607
#            1       0.68      0.55      0.61       393
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.75      0.76      2000
# weighted avg       0.85      0.86      0.86      2000
#
# ------------
# model saved as voting-clf.pkl

# %%
vcHard = VotingClassifier(
    estimators=[('xgboost', XGB.XGBClassifier(random_state=42)), ("rf", RandomForestClassifier(random_state=42)), ("svm", SVC(random_state=42, probability=True))],
    voting='hard'
)

# %%
evaluateAndSave(vcHard, X_resample, X_test, Y_resample, Y_test, 'voting-clf-hard.pkl')
# Out:
# VotingClassifier Accuracy: 0.853
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1607
#            1       0.63      0.59      0.61       393
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.75      0.76      2000
# weighted avg       0.85      0.85      0.85      2000
#
# ------------
# model saved as voting-clf-hard.pkl
